# %% [markdown]
# # Get dataset

# %%
# TODO: Get dataset
import gdown

url = 'https://drive.google.com/uc?id=1S9lZmbaPyGohZ6INfTHhcmOxD9r4DQrR'
output = '/content/denoised_dataset.zip'

gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1S9lZmbaPyGohZ6INfTHhcmOxD9r4DQrR
# From (redirected): https://drive.google.com/uc?id=1S9lZmbaPyGohZ6INfTHhcmOxD9r4DQrR&confirm=t&uuid=efbf2d64-b39e-4e21-bf38-b33c08fc2379
# To: /content/denoised_dataset.zip
# 100%|██████████| 675M/675M [00:03<00:00, 190MB/s]
# '/content/denoised_dataset.zip'

# %%
# prompt: mount google drive

from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# TODO : Extract denoised dataset

# !unzip -q "/content/denoised_dataset.zip" -d "/content/"

# %%
# !ls
# Out:
# denoised_dataset.zip  denoised_enrollments  denoised_test  drive  sample_data

# %% [markdown]
# ### Change the folder paths here

# %%
train_path = "/content/denoised_enrollments"
test_path = "/content/denoised_test"
trials_file_path = "/content/drive/MyDrive/signle-channel-trials.txt"

# %% [markdown]
# I am going to extract embeddings from the audio files with **Noise**

# %%
import os

# %%
# TODO: Extract embeddings
# !pip install xvector-jtubespeech
# Out:
# Collecting xvector-jtubespeech
#   Downloading xvector_jtubespeech-0.0.2-py3-none-any.whl (5.0 kB)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from xvector-jtubespeech) (1.23.5)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from xvector-jtubespeech) (1.11.4)
# Requirement already satisfied: torch>=1.10.2 in /usr/local/lib/python3.10/dist-packages (from xvector-jtubespeech) (2.1.0+cu121)
# Requirement already satisfied: torchaudio>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from xvector-jtubespeech) (2.1.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.2->xvector-jtubespeech) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.2->xvector-jtubespeech) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.2->xvector-jtubespeech) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.2->xvector-jtubespeech) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.2->xvector-jtubespeech) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.2->xvector-jtubespeech) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.2->xvector-jtubespeech) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.2->xvector-jtubespeech) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.2->xvector-jtubespeech) (1.3.0)
# Installing collected packages: xvector-jtubespeech
# Successfully installed xvector-jtubespeech-0.0.2

# %%
train_files = os.listdir(train_path)

# %%
speaker_files = {}

# %%
for file_name in train_files:
  [speaker, audio_f_name] = file_name.split("-")
  if speaker not in speaker_files:
    speaker_files[speaker] = []
    speaker_files[speaker].append(file_name)
  else:
    speaker_files[speaker].append(file_name)

# %%
count = 0
count_files = 0
for k, v in speaker_files.items():
  # print(k)
  count += 1
  count_files += len(v)

print("count", count)
print("count_files", count_files)
# Out:
# count 75
# count_files 225

# %%
# os.listdir(train_path)

# %%
# import torch
# model = torch.hub.load("sarulab-speech/xvector_jtubespeech", "xvector", trust_repo=True)

# %% [markdown]
# # English Embeddings Xvectors

# %%
# !pip install speechbrain
# Out:
# Collecting speechbrain
#   Downloading speechbrain-0.5.16-py3-none-any.whl (630 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 630.6/630.6 kB 3.9 MB/s eta 0:00:00
# Collecting hyperpyyaml (from speechbrain)
#   Downloading HyperPyYAML-1.2.2-py3-none-any.whl (16 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from speechbrain) (1.3.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from speechbrain) (1.23.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from speechbrain) (23.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from speechbrain) (1.11.4)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from speechbrain) (0.1.99)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.10/dist-packages (from speechbrain) (2.1.0+cu121)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (from speechbrain) (2.1.0+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from speechbrain) (4.66.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from speechbrain) (0.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.9->speechbrain) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->speechbrain) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->speechbrain) (6.0.1)
# Collecting ruamel.yaml>=0.17.28 (from hyperpyyaml->speechbrain)
#   Downloading ruamel.yaml-0.18.5-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.4/116.4 kB 13.9 MB/s eta 0:00:00
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain)
#   Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 25.7 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.9->speechbrain) (2.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->speechbrain) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->speechbrain) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->speechbrain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->speechbrain) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.9->speechbrain) (1.3.0)
# Installing collected packages: ruamel.yaml.clib, ruamel.yaml, hyperpyyaml, speechbrain
# Successfully installed hyperpyyaml-1.2.2 ruamel.yaml-0.18.5 ruamel.yaml.clib-0.2.8 speechbrain-0.5.16

# %%
import torchaudio
from speechbrain.pretrained import EncoderClassifier
classifier = EncoderClassifier.from_hparams(source="speechbrain/spkrec-xvect-voxceleb", savedir="pretrained_models/spkrec-xvect-voxceleb")
# Out:
# hyperparams.yaml:   0%|          | 0.00/2.04k [00:00<?, ?B/s]
# embedding_model.ckpt:   0%|          | 0.00/16.9M [00:00<?, ?B/s]
# mean_var_norm_emb.ckpt:   0%|          | 0.00/3.20k [00:00<?, ?B/s]
# classifier.ckpt:   0%|          | 0.00/15.9M [00:00<?, ?B/s]
# label_encoder.txt:   0%|          | 0.00/129k [00:00<?, ?B/s]

# %%
print(train_path)
# Out:
# /content/denoised_enrollments

# %%
# signal, fs =torchaudio.load(audio_path_26_2)
# embeddings = classifier.encode_batch(signal)
# # print(embeddings)
# embeddings = embeddings.view(1, 512)
# embeddings.shape

# %%
import numpy as np
from scipy.io import wavfile
import torch
from torchaudio.compliance import kaldi
import torch.nn.functional as F

# from xvector_jtubespeech import XVector

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using", device)

classifier.to(device)

def extract_xvector(model, wav_path):

    # Load the audio signal
    signal, fs = torchaudio.load(wav_path)

    # Move the signal to the GPU if available
    signal = signal.to(device)

    # # Move the model to the GPU if available
    model = model.to(device)

    # Encode the batch on the GPU
    embeddings = model.encode_batch(signal)

    # Move the embeddings to CPU if necessary
    embeddings = embeddings.to("cpu")

    # Reshape the tensor
    xvector = embeddings.view(1, 512)

    return xvector
# Out:
# Using cuda

# %%
import numpy as np
from scipy.io import wavfile
import torch
from torchaudio.compliance import kaldi
import torch.nn.functional as F

device = "cpu"
# Assuming 'classifier' is your model instance
classifier.to(device)

def extract_xvector(model, wav_path):

    # Load the audio signal
    signal, fs = torchaudio.load(wav_path)

    # Move the signal to the GPU if available
    signal = signal.to(device)

    # Move the model to the same device as the signal
    # model = model.to(device)

    # Encode the batch on the GPU
    embeddings = model.encode_batch(signal)

    # Move the embeddings to CPU if necessary
    embeddings = embeddings.to(device)

    # Reshape the tensor
    xvector = embeddings.view(1, 512)

    return xvector

# %%
speaker_files["spk_2"]
# Out:
# ['spk_2-2_1_1_0_d5_ch5.wav',
#  'spk_2-2_1_1_0_d6_ch5.wav',
#  'spk_2-2_1_1_1_d3_ch5.wav']

# %%
audio_path_2_0 = train_path + "/" + speaker_files["spk_2"][0]
audio_path_2_1 = train_path + "/" + speaker_files["spk_2"][1]
audio_path_2_2 = train_path + "/" + speaker_files["spk_2"][2]

# %%
speaker_files["spk_26"]
# Out:
# ['spk_26-26_38_0_0_d3_ch5.wav',
#  'spk_26-26_38_0_0_d4_ch5.wav',
#  'spk_26-26_38_0_0_d1_ch5.wav']

# %%
audio_path_26_0 = train_path + "/" + speaker_files["spk_26"][0]
audio_path_26_1 = train_path + "/" + speaker_files["spk_26"][1]
audio_path_26_2 = train_path + "/" + speaker_files["spk_26"][2]

# %%
# _, wav_2_0 = wavfile.read(audio_path_2_0) # 16kHz mono
# _, wav_2_1 = wavfile.read(audio_path_2_1)
# _, wav_2_2 = wavfile.read(audio_path_2_2)

# _, wav_26_0 = wavfile.read(audio_path_26_0) # 16kHz mono
# _, wav_26_1 = wavfile.read(audio_path_26_1)
# _, wav_26_2 = wavfile.read(audio_path_26_2)

# xvector_2_0 = extract_xvector(model, wav_2_0) # (512, )
# xvector_2_1 = extract_xvector(model, wav_2_1)
# xvector_2_2 = extract_xvector(model, wav_2_2)

# xvector_26_0 = extract_xvector(model, wav_26_0) # (512, )
# xvector_26_1 = extract_xvector(model, wav_26_1)
# xvector_26_2 = extract_xvector(model, wav_26_2)


# # xvector2_2 = extract_xvector(model, )

# %%
# xvector_26_0.shape

# %%
# tensor_2_0 = torch.tensor(xvector_2_0)
# tensor_2_1 = torch.tensor(xvector_2_1)
# tensor_2_2 = torch.tensor(xvector_2_2)

# tensor_26_0 = torch.tensor(xvector_26_0)
# tensor_26_1 = torch.tensor(xvector_26_1)
# tensor_26_2 = torch.tensor(xvector_26_2)

# %%
# tensor_26_0.shape

# %% [markdown]
# # Calculate the Cosine Distance

# %%
import torch
import torch.nn.functional as F

# # Compute cosine similarity
# cosine_similarity_2_0_2_1 = F.cosine_similarity(tensor_2_0, tensor_2_1, dim=0)
# cosine_similarity_2_0_26_1 = F.cosine_similarity(tensor_2_0, tensor_26_1, dim=0)

# %%
# cosine_similarity_2_0_26_1.item()

# %%
# # Compute cosine distance (1 - cosine similarity)
# cosine_distance_2_0_2_1 = 1 - cosine_similarity_2_0_2_1.item()
# cosine_distance_2_0_26_1 = 1 - cosine_similarity_2_0_26_1.item()

# print("Cosine Similarity: _2_0_2_1", cosine_similarity_2_0_2_1.item())
# print("Cosine Distance: _2_0_2_1", cosine_distance_2_0_2_1)
# print()

# print("Cosine Similarity: _2_0_26_1", cosine_similarity_2_0_26_1.item())
# # print("Cosine Distance: _2_0_26_1", cosine_distance_2_0_26_1)

# %%
speaker_names = list(speaker_files.keys())

# %% [markdown]
# ### Store X-Vectors of speakers in a dictionary

# %%
speaker_xvectors = {}

# %%
device
# Out:
# 'cpu'

# %%
classifier.to(device);

# %%
for speaker in speaker_names:
  audio_path = train_path + "/" + speaker_files[speaker][-1]
  # _, wav_file = wavfile.read(audio_path) # 16kHz mono
  # classifier.to("cpu")

  speaker_xvectors[speaker] = torch.tensor(extract_xvector(classifier, audio_path))
# Out:
# <ipython-input-53-dcf0c49aaf0b>:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   speaker_xvectors[speaker] = torch.tensor(extract_xvector(classifier, audio_path))

# %%
speaker_xvectors["spk_2"].shape
# Out:
# torch.Size([1, 512])

# %%
len(list(speaker_xvectors.keys()))
# Out:
# 75

# %%
len(os.listdir(test_path))
# Out:
# 10332

# %%
trials_file = open(trials_file_path, "r")
trials = trials_file.readlines()
# trials

# %%
# calculate_cosine_similarity
cosine_similarity_list = []
cosine_distance_list = []

# %%
def get_trial(index:int):
  trial_name = trials[index]
  trial_spk, trial_wav = trial_name.split("-")
  trial_wav = trial_wav.split("\n")
  trial_audio_name = trial_wav[0]
  trial_wav = trial_audio_name + ".wav"

  audio_path = test_path + "/" + trial_wav

  return (trial_name, trial_spk, trial_audio_name, trial_wav, audio_path)

# %%
speaker_xvectors["spk_2"].shape
# Out:
# torch.Size([1, 512])

# %%
cos_sim_file = open("/content/drive/MyDrive/sp_cup_output/" +"english_cos_sim.txt","w")
cos_dist_file = open("/content/drive/MyDrive/sp_cup_output/english_cos_dist.txt","w")

# %%
cos_sim_file.close()
cos_dist_file.close()

# %%
cos_sim_file = open("/content/drive/MyDrive/sp_cup_output/english_cos_sim.txt","a")
cos_dist_file = open("/content/drive/MyDrive/sp_cup_output/english_cos_dist.txt","a")

# %%
# trials

# %%
# trials
cos_sim_content = ""
cos_dist_content = ""

# %%
# For each trail calculate the xvector for each
for i in range(len(trials)):
  # print(get_trial(i))

  trial_key, test_spk, test_audio_name, test_wav, test_audio_path = get_trial(i)

  # Calculate the xvector tensor for test_audio
  audio_path = train_path + "/" + speaker_files[speaker][-1]
  # _, wav_file = wavfile.read(test_audio_path) # 16kHz mono
  test_audio_xvector = torch.tensor(extract_xvector(classifier, audio_path))

  # Test speaker xvector
  test_spk_xvector = speaker_xvectors[test_spk]

  # Calculate cosine similarity
  cos_sim = F.cosine_similarity(test_spk_xvector, test_audio_xvector, dim=1).item()

  # Calculate cosine distance
  cos_dist = 1 - cos_sim
  # print(cos_sim, cos_dist)

  # Round values
  cos_sim_round = round(cos_sim, 7)
  cos_dist_round = round(cos_dist, 7)

  # Save to list
  cosine_similarity_list.append(cos_sim)
  cosine_distance_list.append(cos_dist)
  # break

  # Save to files
  cos_sim_line = test_spk + "\t" + test_audio_name + "\t" + str(cos_sim_round) + "\n"
  cos_dist_line = test_spk + "\t" + test_audio_name + "\t" + str(cos_dist_round) + "\n"
  # print(cos_sim_line)
  cos_sim_content += cos_sim_line
  cos_dist_content += cos_dist_line
  # print(cos_dist_line)

  if i % 1000 == 0:
    print(i)

  # if i == 500:
  #   break

cos_sim_content = cos_sim_content[:-1]
cos_dist_content = cos_dist_content[:-1]

cos_sim_file.write(cos_sim_content)
cos_dist_file.write(cos_dist_content)

cos_sim_file.close()
cos_dist_file.close()
# Out:
# <ipython-input-95-fc7f2e4e69b2>:10: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   test_audio_xvector = torch.tensor(extract_xvector(classifier, audio_path))
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 11000
# 12000
# 13000
# 14000
# 15000
# 16000
# 17000
# 18000
# 19000
# 20000
# 21000
# 22000
# 23000
# 24000
# 25000
# 26000
# 27000
# 28000
# 29000
# 30000
# 31000
# 32000
# 33000
# 34000
# 35000
# 36000
# 37000
# 38000
# 39000
# 40000
# 41000
# 42000
# 43000
# 44000
# 45000
# 46000
# 47000
# 48000
# 49000
# 50000
# 51000
# 52000
# 53000
# 54000
# 55000
# 56000
# 57000
# 58000
# 59000
# 60000
# 61000
# 62000
# 63000
# 64000
# 65000
# 66000
# 67000
# 68000
# 69000
# 70000
# 71000
# 72000
# 73000
# 74000
# 75000
# 76000
# 77000
# 78000
# 79000
# 80000
# 81000
# 82000
# 83000
# 84000
# 85000
# 86000
# 87000
# 88000
# 89000
# 90000
# 91000
# 92000
# 93000
# 94000
# 95000
# 96000
# 97000
# 98000
# 99000
# 100000
# 101000
# 102000

# %%
# audio_path = test_path + "/" + trial_wav
# audio_path

# %%
# TODO: Calculate the Cosine Distance
# TODO : Save the cosine ditances to a text file
